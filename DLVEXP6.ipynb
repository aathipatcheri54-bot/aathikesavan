# %% [markdown]
# <a href="https://colab.research.google.com/github/aathipatcheri54-bot/aathikesavan/blob/main/DLVEXP6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers, models

num_samples = 100
timesteps = 10
height, width, channels = 64, 64, 1

x_data = np.random.rand(num_samples, timesteps, height, width, channels)
y_data = np.random.randint(0, 3, size=(num_samples,))

# Reshape and split data
x_data = x_data.reshape(num_samples, timesteps, -1)
x_train, x_test = x_data[:80], x_data[80:]
y_train, y_test = y_data[:80], y_data[80:]

# Build the model using the recommended Input layer
model = models.Sequential([
    layers.Input(shape=(timesteps, height * width * channels)),
    layers.LSTM(64),
    layers.Dense(32, activation='relu'),
    layers.Dense(3, activation='softmax')
])

model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Train
model.fit(x_train, y_train, epochs=5, batch_size=8, validation_split=0.2)

# Evaluate
loss, acc = model.evaluate(x_test, y_test)
print(f"Test Accuracy: {acc * 100:.2f}%")

# Predict
sample = x_test[0:1]
predicted = model.predict(sample)
print("Predicted Class:", np.argmax(predicted))
# Out:
# Epoch 1/5
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 105ms/step - accuracy: 0.2969 - loss: 1.3888 - val_accuracy: 0.3125 - val_loss: 1.1080
# Epoch 2/5
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.3438 - loss: 1.0945 - val_accuracy: 0.3125 - val_loss: 1.1003
# Epoch 3/5
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.3438 - loss: 1.0988 - val_accuracy: 0.3750 - val_loss: 1.0983
# Epoch 4/5
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.5312 - loss: 1.0904 - val_accuracy: 0.3750 - val_loss: 1.0966
# Epoch 5/5
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.4844 - loss: 1.0837 - val_accuracy: 0.3125 - val_loss: 1.0974
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 311ms/step - accuracy: 0.2500 - loss: 1.1033
# Test Accuracy: 25.00%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step
# Predicted Class: 2
