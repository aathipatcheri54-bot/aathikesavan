# %% [markdown]
# <a href="https://colab.research.google.com/github/aathipatcheri54-bot/aathikesavan/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

def sigmoid(x):
    return 1 / (1 + np.exp(-x))

def sigmoid_derivative(x):
    return x * (1 - x)

X = np.array([[0,0], [0,1], [1,0], [1,1]])
Y = np.array([[0], [1], [1], [0]])

# Implementation of Simple Neural Network Ex 2
np.random.seed(1)
weights = 2 * np.random.random((2, 1)) - 1

for epoch in range(10000):
    input_layer = X
    output = sigmoid(np.dot(input_layer, weights))
    error = Y - output
    adjustments = error * sigmoid_derivative(output)
    weights += np.dot(input_layer.T, adjustments)

print("Predicted Output after training:")
print(output)
# Out:
# Predicted Output after training:
# [[0.5]
#  [0.5]
#  [0.5]
#  [0.5]]
